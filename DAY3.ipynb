# %%
list = input("enter the fruits separated by space").split()
print(list)
# Out:
# enter the fruits separated by space banana mango orange grapes kiwi
# ['banana', 'mango', 'orange', 'grapes', 'kiwi']

# %%
list = input("enter the fruits separated by space").split()
first = list[0]
last = list[-1]
print(first)
print(last)
# Out:
# enter the fruits separated by space banana apple orange
# banana
# orange

# %%
list = input("enter the fruits separated by space").split()
name = input("enter a name")
list.append(name)
print(list)
# Out:
# enter the fruits separated by space kiwi orange guava banana
# enter a name ayushi
# ['kiwi', 'orange', 'guava', 'banana', 'ayushi']

# %%
list = input("enter the fruits separated by space").split()
print(list)
list.remove("banana")
print(list)
# Out:
# enter the fruits separated by space banana orange mango kiwi
# ['banana', 'orange', 'mango', 'kiwi']
# ['orange', 'mango', 'kiwi']

# %%
list = input("enter the elements separated by space").split()
print(list)
length = len(list)
print(length)
# Out:
# enter the elements separated by space a bs c de f
# ['a', 'bs', 'c', 'de', 'f']
# 5

# %%
numbers = [int(x) for x in input("enter numbers separated by spaces ").split()]
numbers.sort()
print(numbers)
numbers.sort(reverse=True)
print(numbers)
# Out:
# enter numbers separated by spaces  23 56 78 43 90 45
# [23, 43, 45, 56, 78, 90]
# [90, 78, 56, 45, 43, 23]

# %%
numbers = [int(x) for x in input("enter numbers separated by spaces ").split()]
print(max(numbers))
print(min(numbers))
# Out:
# enter numbers separated by spaces  7686 764 76 6336 785757
# 785757
# 76

# %%
numbers = [int(x) for x in input("enter numbers separated by spaces ").split()]
print("printing items")
for item in numbers :
 print(item)
# Out:
# enter numbers separated by spaces  68778 767 78 87876 445 9808 866
# printing items
# 68778
# 767
# 78
# 87876
# 445
# 9808
# 866

# %%
a= {12,23,45,67,7}
a.add(13)
print(a)
a.remove(12)
print(a)
# Out:
# {13, 67, 23, 7, 12, 45}
# {13, 67, 23, 7, 45}

# %%
student = {
    "name" : "ayushi",
    "age" : 12,  
" branch" : "cse" }
print(student["name"])
# Out:
# ayushi

# %%
file = open("Name.txt" , "r")
print(file.read())
file.close()
# Out:
# Ayushi
# Priya
# harshit
# puru
# Rishabh
# diya
# anant
# raunak
# kishan
# aman

# %%
file = open("Places.txt" , "r")
data = file.read()
print(data)
file.close()
# Out:
# Grand Canyon
#
# Mount Everest
#
# Great Barrier Reef
#
# Salar de Uyuni
#
# Fuji-Hakone-Izu National Park
#
# Ha Long Bay
#
# Serengeti National Park
#
# Banff National Park
#
# Galápagos Islands
#
# Plitvice Lakes National Park
#
# Giants Causeway
#
# Sahara Desert
#
# Jeju Island
#
# The Amazon Rainforest
#
# Machu Picchu
#
# The Pyramids of Giza
#
# Petra
#
# The Colosseum
#
# Angkor Wat
#
# The Great Wall
#
# Acropolis of Athens
#
# Stonehenge
#
# Chichen Itza
#
# Pompeii
#
# Alhambra
#
# Tikal
#
# The Terracotta Army
#
# Kyoto
#
# Venice
#
# Times Square
#
# Eiffel Tower
#
# Sydney Opera House
#
# Taj Mahal
#
# Burj Khalifa
#
# Santorini
#
# Rio de Janeiro
#
# Marrakesh Medina
#
# Dubrovnik Old Town
#
# Statue of Liberty
#
# Big Ben
#
# Chefchaouen
#
# Svalbard
#
# Cappadocia
#
# Antarctica
#
# Hallstatt
#
# Rotorua
#
# Reykjavík
#
# Mont Saint-Michel
#
# Oaxaca City
#
# Easter Island
