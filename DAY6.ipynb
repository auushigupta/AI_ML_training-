# %%
import pandas as pd

marks = pd.Series([12,23,45,55])
print(marks)
# Out:
# 0    12
# 1    23
# 2    45
# 3    55
# dtype: int64

# %%
df = pd.read_csv("marks.txt")
print(df)
# Out:
#   Student   Math  Science  English  Computer  Social Studies  Total
# 0  Aarav     78    85       74       90        81...
# 1  Diya      88    79       92       87        84...
# 2  Ishaan    69    73       70       75        72...
# 3  Kavya     91    89       95       93        90...
# 4  Vivaan    76    80       78       82        77...
# 5  Anaya     84    86       88       85        87...
# 6  Aditya    72    68       75       70        74...
# 7  Meera     95    94       96       97        93...
# 8  Rohan     81    83       79       80        82...
# 9  Siya      87    90       85       88        91...

# %%
marks = pd.Series([12,56,78],index=['a' , 'b', 'c'])
print(marks)
# Out:
# a    12
# b    56
# c    78
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv("marks.txt")
print(df)
print(df.head())
print(df.tail())
print(df.shape)
print(df.columns)

print(df.index)
print(df.info())
print(df.describe())
# Out:
#   Student   Math  Science  English  Computer  Social Studies  Total
# 0  Aarav     78    85       74       90        81...
# 1  Diya      88    79       92       87        84...
# 2  Ishaan    69    73       70       75        72...
# 3  Kavya     91    89       95       93        90...
# 4  Vivaan    76    80       78       82        77...
# 5  Anaya     84    86       88       85        87...
# 6  Aditya    72    68       75       70        74...
# 7  Meera     95    94       96       97        93...
# 8  Rohan     81    83       79       80        82...
# 9  Siya      87    90       85       88        91...
#   Student   Math  Science  English  Computer  Social Studies  Total
# 0  Aarav     78    85       74       90        81...
# 1  Diya      88    79       92       87        84...
# 2  Ishaan    69    73       70       75        72...
# 3  Kavya     91    89       95       93        90...
# 4  Vivaan    76    80       78       82        77...
# ...

# %%
df = pd.read_csv("new.txt")
print(df)
print(df.head())
print(df.tail())
print(df.shape)
print(df.columns)

print(df.index)
print(df.info())
print(df.describe())
print(df.iloc[0])
# Out:
#                                 EmployeeID  Name Department  Salary
# E101 Aarav Sharma    HR                                       45000
# E102 Diya Verma      Finance                                  52000
# E103 Vihaan Singh    IT                                       60000
# E104 Ananya Gupta    Marketing                                48000
# E105 Arjun Mehta     IT                                       65000
# E106 Kavya Nair      HR                                       47000
# E107 Rohan Kapoor    Finance                                  55000
# E108 Meera Joshi     Marketing                                50000
# E109 Aditya Rao      IT                                       72000
# E110 Ishita Malhotra HR                                       46000
# E111 Karan Patel     Finance                                  58000
# E112 Sneha Iyer      Marketing                                51000
# E113 Yash Chauhan    IT                                       69000
# ...

# %%
import pandas as pd 
df = pd.read_csv("newdata.txt")
print(df)
#check null values
print(df.isnull())
# Out:
#    Employee_ID    Name Department   Salary  Experience
# 0          101    Aman         HR  45000.0         2.0
# 1          102   Priya         IT  55000.0         3.0
# 2          103   Rahul    Finance      NaN         4.0
# 3          104    Neha         IT  62000.0         NaN
# 4          105   Arjun        NaN  48000.0         2.0
# 5          106  Simran  Marketing  51000.0         3.0
# 6          107   Karan    Finance  59000.0         NaN
# 7          108     NaN         HR  47000.0         1.0
# 8          109   Meera  Marketing      NaN         5.0
# 9          110   Rohit         IT  65000.0         4.0
#    Employee_ID   Name  Department  Salary  Experience
# 0        False  False       False   False       False
# 1        False  False       False   False       False
# 2        False  False       False    True       False
# 3        False  False       False   False        True
# 4        False  False        True   False       False
# ...

# %%
df = pd.read_csv("marks.txt", sep = r"\s+" , engine = "python")
df["Hindi"] = [50, 56,78,78,78,39,82,67,66,67]
print(df)
df.groupby("Student")["Science"].sum()
# Out:
#   Student  Math  Science  English  Computer  Social  Studies  Total  Hindi
# 0   Aarav    78       85       74        90      81      408    NaN     50
# 1    Diya    88       79       92        87      84      430    NaN     56
# 2  Ishaan    69       73       70        75      72      359    NaN     78
# 3   Kavya    91       89       95        93      90      458    NaN     78
# 4  Vivaan    76       80       78        82      77      393    NaN     78
# 5   Anaya    84       86       88        85      87      430    NaN     39
# 6  Aditya    72       68       75        70      74      359    NaN     82
# 7   Meera    95       94       96        97      93      475    NaN     67
# 8   Rohan    81       83       79        80      82      405    NaN     66
# 9    Siya    87       90       85        88      91      441    NaN     67
# Student
# Aarav     85
# Aditya    68
# Anaya     86
# Diya      79
# Ishaan    73
# Kavya     89
# Meera     94
# Rohan     83
# Siya      90
# ...

# %%
df.groupby("Student")["Science"].mean()
# Out:
# Student
# Aarav     85.0
# Aditya    68.0
# Anaya     86.0
# Diya      79.0
# Ishaan    73.0
# Kavya     89.0
# Meera     94.0
# Rohan     83.0
# Siya      90.0
# Vivaan    80.0
# Name: Science, dtype: float64

# %%
group = df.groupby("Student")["Science"].sum()
print(group["Aditya"])
# Out:
# 68

# %%
df.groupby("Student")["Science"].count()
# Out:
# Student
# Aarav     1
# Aditya    1
# Anaya     1
# Diya      1
# Ishaan    1
# Kavya     1
# Meera     1
# Rohan     1
# Siya      1
# Vivaan    1
# Name: Science, dtype: int64

# %%
# %pip install openpyxl

# %%
import pandas as pd
df =  pd.read_excel("salesx.xlsx")
print(df)
# Out:
#     Order_ID  Order_Date Region Salesperson Product_Category  \
# 0       1001  2026-01-05  North        Aman      Electronics
# 1       1002  2026-01-07  South       Priya        Furniture
# 2       1003  2026-01-10   East       Rahul      Electronics
# 3       1004  2026-01-12   West        Neha       Appliances
# 4       1005  2026-01-15  North       Arjun        Furniture
# 5       1006  2026-01-18  South      Simran      Electronics
# 6       1007  2026-01-20   East       Karan       Appliances
# 7       1008  2026-01-22   West         NaN      Electronics
# 8       1009  2026-01-25  North       Meera        Furniture
# 9       1010  2026-01-28  South       Rohit      Electronics
# 10      1011  2026-02-02   East        Aman       Appliances
# 11      1012  2026-02-05   West       Priya        Furniture
# 12      1013  2026-02-08  North       Rahul      Electronics
# 13      1014  2026-02-11  South        Neha       Appliances
# ...

# %%
df = pd.read_csv("newdata.txt" , sep = ",")
print(df)
# Out:
#    Employee_ID    Name Department   Salary  Experience
# 0          101    Aman         HR  45000.0         2.0
# 1          102   Priya         IT  55000.0         3.0
# 2          103   Rahul    Finance      NaN         4.0
# 3          104    Neha         IT  62000.0         NaN
# 4          105   Arjun        NaN  48000.0         2.0
# 5          106  Simran  Marketing  51000.0         3.0
# 6          107   Karan    Finance  59000.0         NaN
# 7          108     NaN         HR  47000.0         1.0
# 8          109   Meera  Marketing      NaN         5.0
# 9          110   Rohit         IT  65000.0         4.0

# %%
print(df.isnull())
# Out:
#    Employee_ID   Name  Department  Salary  Experience
# 0        False  False       False   False       False
# 1        False  False       False   False       False
# 2        False  False       False    True       False
# 3        False  False       False   False        True
# 4        False  False        True   False       False
# 5        False  False       False   False       False
# 6        False  False       False   False        True
# 7        False   True       False   False       False
# 8        False  False       False    True       False
# 9        False  False       False   False       False

# %%
print(df.isnull().sum())
# Out:
# Employee_ID    0
# Name           1
# Department     1
# Salary         2
# Experience     2
# dtype: int64

# %%
df.fillna("not available")
# Out:
#    Employee_ID           Name     Department         Salary     Experience
# 0          101           Aman             HR        45000.0            2.0
# 1          102          Priya             IT        55000.0            3.0
# 2          103          Rahul        Finance  not available            4.0
# 3          104           Neha             IT        62000.0  not available
# 4          105          Arjun  not available        48000.0            2.0
# 5          106         Simran      Marketing        51000.0            3.0
# 6          107          Karan        Finance        59000.0  not available
# 7          108  not available             HR        47000.0            1.0
# 8          109          Meera      Marketing  not available            5.0
# 9          110          Rohit             IT        65000.0            4.0

# %%
print(df.isnull().sum())
df.fillna({
    
    "Salary": 50000.0,
    "Experience" : 3,
    "Department" :"HR",
    "Name" :"not given"
})
# Out:
# Employee_ID    0
# Name           0
# Department     0
# Salary         0
# Experience     0
# dtype: int64
#    Employee_ID       Name Department   Salary  Experience
# 0          101       Aman         HR  45000.0         2.0
# 1          102      Priya         IT  55000.0         3.0
# 2          103      Rahul    Finance  50000.0         4.0
# 3          104       Neha         IT  62000.0         3.0
# 4          105      Arjun         HR  48000.0         2.0
# 5          106     Simran  Marketing  51000.0         3.0
# 6          107      Karan    Finance  59000.0         3.0
# 7          108  not given         HR  47000.0         1.0
# 8          109      Meera  Marketing  50000.0         5.0
# 9          110      Rohit         IT  65000.0         4.0

# %%
import pandas as pd
df = pd.read_csv("DATA.txt" , sep = ",")
print(df)
# Out:
#        ID           Name   Age  Gender    City    Salary
# 0       1  Aisha Agarwal  59.0  Female  Jaipur  105104.0
# 1       2    Pooja Joshi  58.0  Female  Indore   21631.0
# 2       3    Diya Mishra  27.0  Female     NaN  107499.0
# 3       4    Sneha Joshi  52.0  Female     NaN   93543.0
# 4       5   Pooja Mishra  42.0  Female  Bhopal   21470.0
# ..    ...            ...   ...     ...     ...       ...
# 995   996    Arjun Yadav  40.0    Male  Mumbai   37298.0
# 996   997    Arjun Patel   NaN    Male     NaN   68986.0
# 997   998    Pooja Gupta  41.0  Female  Bhopal   25696.0
# 998   999     Riya Joshi  39.0  Female   Patna   98158.0
# 999  1000   Vivaan Gupta  45.0    Male  Kanpur   97382.0
#
# [1000 rows x 6 columns]

# %%
#selecting data
print(df["Name"])
print(df.loc[0])
print(df.loc[2,"Gender"])
# Out:
# 0      Aisha Agarwal
# 1        Pooja Joshi
# 2        Diya Mishra
# 3        Sneha Joshi
# 4       Pooja Mishra
#            ...
# 995      Arjun Yadav
# 996      Arjun Patel
# 997      Pooja Gupta
# 998       Riya Joshi
# 999     Vivaan Gupta
# Name: Name, Length: 1000, dtype: str
# ID                    1
# Name      Aisha Agarwal
# Age                59.0
# Gender           Female
# City             Jaipur
# Salary         105104.0
# Name: 0, dtype: object
# Female

# %%
#data cleaning
print(df.isnull())
print(df.isnull().sum())
# Out:
#         ID   Name    Age  Gender   City  Salary
# 0    False  False  False   False  False   False
# 1    False  False  False   False  False   False
# 2    False  False  False   False   True   False
# 3    False  False  False   False   True   False
# 4    False  False  False   False  False   False
# ..     ...    ...    ...     ...    ...     ...
# 995  False  False  False   False  False   False
# 996  False  False   True   False   True   False
# 997  False  False  False   False  False   False
# 998  False  False  False   False  False   False
# 999  False  False  False   False  False   False
#
# [1000 rows x 6 columns]
# ID          0
# Name        0
# Age       100
# Gender    100
# City      100
# Salary    100
# dtype: int64

# %%
df.fillna(1)
# Out:
#        ID           Name   Age  Gender    City    Salary
# 0       1  Aisha Agarwal  59.0  Female  Jaipur  105104.0
# 1       2    Pooja Joshi  58.0  Female  Indore   21631.0
# 2       3    Diya Mishra  27.0  Female       1  107499.0
# 3       4    Sneha Joshi  52.0  Female       1   93543.0
# 4       5   Pooja Mishra  42.0  Female  Bhopal   21470.0
# ..    ...            ...   ...     ...     ...       ...
# 995   996    Arjun Yadav  40.0    Male  Mumbai   37298.0
# 996   997    Arjun Patel   1.0    Male       1   68986.0
# 997   998    Pooja Gupta  41.0  Female  Bhopal   25696.0
# 998   999     Riya Joshi  39.0  Female   Patna   98158.0
# 999  1000   Vivaan Gupta  45.0    Male  Kanpur   97382.0
#
# [1000 rows x 6 columns]

# %%
df.fillna({
    "Age" : 20,
    "Gender" : "M/F",
    "City" : "not given",
    "Salary" : 50000.0
})
# Out:
#        ID           Name   Age  Gender       City    Salary
# 0       1  Aisha Agarwal  59.0  Female     Jaipur  105104.0
# 1       2    Pooja Joshi  58.0  Female     Indore   21631.0
# 2       3    Diya Mishra  27.0  Female  not given  107499.0
# 3       4    Sneha Joshi  52.0  Female  not given   93543.0
# 4       5   Pooja Mishra  42.0  Female     Bhopal   21470.0
# ..    ...            ...   ...     ...        ...       ...
# 995   996    Arjun Yadav  40.0    Male     Mumbai   37298.0
# 996   997    Arjun Patel  20.0    Male  not given   68986.0
# 997   998    Pooja Gupta  41.0  Female     Bhopal   25696.0
# 998   999     Riya Joshi  39.0  Female      Patna   98158.0
# 999  1000   Vivaan Gupta  45.0    Male     Kanpur   97382.0
#
# [1000 rows x 6 columns]

# %%
df.dropna()
df.isnull().sum()
# Out:
# ID        0
# Name      0
# Age       0
# Gender    0
# City      0
# Salary    0
# dtype: int64

# %%
#filtering data
df[(df["Salary"]>50000.0) & (df["Age"]<50.0)]
# Out:
#        ID             Name   Age  Gender     City    Salary
# 9      10  Krishna Agarwal  22.0    Male   Kanpur   73430.0
# 11     12    Krishna Singh  37.0    Male   Indore   70349.0
# 15     16      Kavya Kumar  40.0  Female    Delhi  104822.0
# 17     18    Kavya Agarwal  22.0  Female   Mumbai   99743.0
# 37     38      Sneha Yadav  45.0  Female   Jaipur   75327.0
# ..    ...              ...   ...     ...      ...       ...
# 985   986        Sai Verma  28.0    Male  Lucknow   59586.0
# 988   989     Sneha Mishra  18.0  Female     Pune   64008.0
# 989   990      Pooja Gupta  21.0  Female   Indore   74117.0
# 998   999       Riya Joshi  39.0  Female    Patna   98158.0
# 999  1000     Vivaan Gupta  45.0    Male   Kanpur   97382.0
#
# [352 rows x 6 columns]

# %%
#add columns 
df["Locality"] = "Urban"
print(df)
# Out:
#        ID           Name   Age  Gender    City    Salary Locality
# 0       1  Aisha Agarwal  59.0  Female  Jaipur  105104.0    Urban
# 1       2    Pooja Joshi  58.0  Female  Indore   21631.0    Urban
# 4       5   Pooja Mishra  42.0  Female  Bhopal   21470.0    Urban
# 5       6   Vivaan Joshi  60.0    Male   Patna   58496.0    Urban
# 6       7   Meera Mishra  52.0  Female   Noida   88180.0    Urban
# ..    ...            ...   ...     ...     ...       ...      ...
# 994   995    Neha Mishra  50.0  Female   Noida  105665.0    Urban
# 995   996    Arjun Yadav  40.0    Male  Mumbai   37298.0    Urban
# 997   998    Pooja Gupta  41.0  Female  Bhopal   25696.0    Urban
# 998   999     Riya Joshi  39.0  Female   Patna   98158.0    Urban
# 999  1000   Vivaan Gupta  45.0    Male  Kanpur   97382.0    Urban
#
# [658 rows x 7 columns]

# %%
#groupby
df.groupby("Name")["Salary"].sum()
# Out:
# Name
# Aarav Agarwal    126551.0
# Aarav Gupta       74161.0
# Aarav Joshi      172472.0
# Aarav Kumar      260830.0
# Aarav Mishra      68685.0
#                    ...
# Vivaan Kumar     335650.0
# Vivaan Mishra     54085.0
# Vivaan Patel     336659.0
# Vivaan Sharma    214707.0
# Vivaan Verma     210102.0
# Name: Salary, Length: 194, dtype: float64

# %%
df.groupby("Name")["Salary"].max()
# Out:
# Name
# Aarav Agarwal     68279.0
# Aarav Gupta       53576.0
# Aarav Joshi      107791.0
# Aarav Kumar      109411.0
# Aarav Mishra      68685.0
#                    ...
# Vivaan Kumar     112206.0
# Vivaan Mishra     54085.0
# Vivaan Patel      85929.0
# Vivaan Sharma     95816.0
# Vivaan Verma      95802.0
# Name: Salary, Length: 194, dtype: float64

# %%
df.groupby("Name")["Salary"].count()
# Out:
# Name
# Aarav Agarwal    2
# Aarav Gupta      2
# Aarav Joshi      2
# Aarav Kumar      3
# Aarav Mishra     1
#                 ..
# Vivaan Kumar     5
# Vivaan Mishra    1
# Vivaan Patel     6
# Vivaan Sharma    3
# Vivaan Verma     4
# Name: Salary, Length: 194, dtype: int64
